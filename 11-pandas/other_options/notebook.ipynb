# %%
import pandas as pd
df = pd.read_csv("orders.csv")

df.head()

# %%
df = pd.read_excel("Over70.xlsx")
df.head()
# Out:
#   Dwelling_HH  Dwelling_No  HH_Number  Source  RefWeekNo  \
# 0    400270_1       400270          1       4          6
# 1    400270_1       400270          1       4          6
# 2    402093_1       402093          1       4          8
# 3    403764_1       403764          1       4          7
# 4    405225_1       405225          1       4          9
#
#                          HouseName    Prefix                 Street  \
# 0           SANT ANNA COURT FLAT 5      TRIQ            SAN LAWRENZ
# 1           SANT ANNA COURT FLAT 5      TRIQ            SAN LAWRENZ
# 2        21, PRINCESS FLATS FLAT 2  TRIQ IL-  PRINCIPESSA MARGERITA
# 3  BLOCK B FLAT 27 HILLTOP GARDENS   TRIQ L-                INKWINA
# 4                               40   TELGHET             BIRKIRKARA
#
#          Locality_MGC_FT FamilyName  ...  Unnamed: 23  Unnamed: 24  \
# 0            SAN LAWRENZ       MAYO  ...          NaN          NaN
# 1            SAN LAWRENZ       MAYO  ...          NaN          NaN
# ...

# %%
df.tail()

# %%
df.info()

# %%
df.describe()

# %%
df.columns

# %%
df.index

# %%
df.columns

# %%
df["Dwelling_HH"]

# %%
df[df["Source"] == 4]

# %%
pd.unique()

# %%
uniqueHH = df.drop_duplicates(subset=["Dwelling_HH"]).sort_values(by="Source", ascending=True)
#print(uniqueHH)

uniqueHH.to_csv("Source4.csv")
